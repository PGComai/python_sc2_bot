# %%
import nest_asyncio
nest_asyncio.apply()

from sc2 import maps
from sc2.bot_ai import BotAI
from sc2.data import Difficulty, Race
from sc2.ids.ability_id import AbilityId
from sc2.ids.buff_id import BuffId
from sc2.ids.unit_typeid import UnitTypeId
from sc2.main import run_game
from sc2.player import Bot, Computer
import random
import math
import numpy as np; from numpy import linspace, pi

### needs to be a state machine

class BBBot(BotAI):
    # pylint: disable=R0912
    async def on_step(self, iteration):
        if iteration % 5 == 0:
            self.tick5 = True
        else:
            self.tick5 = False
        
        bases = self.townhalls
        num_bases = self.townhalls.amount
        num_workers = self.workers.amount
        if num_bases > 0:
            worker_ratio = num_workers/num_bases
        else:
            worker_ratio = 0

        await self.distribute_workers()
        await self.build_supply()
        await self.build_rax()
        await self.build_marines()
        await self.marine_patrol()

        if worker_ratio < 15:
            await self.build_workers()
        else:
            await self.expand()

    async def build_workers(self):
        for cc in self.townhalls.ready.idle:
            if self.can_afford(UnitTypeId.SCV):
                cc.train(UnitTypeId.SCV)

    async def expand(self):
        if self.townhalls.amount < 3 and self.can_afford(UnitTypeId.COMMANDCENTER):
            await self.expand_now()

    async def build_supply(self):
        ccs = self.townhalls(UnitTypeId.COMMANDCENTER).ready
        if ccs.exists:
            cc = ccs.first
            if self.supply_left < 4 and not self.already_pending(UnitTypeId.SUPPLYDEPOT):
                if self.can_afford(UnitTypeId.SUPPLYDEPOT):
                    await self.build(UnitTypeId.SUPPLYDEPOT, near=cc.position.towards(self.game_info.map_center, 5))

    async def build_rax(self):
        ccs = self.townhalls.ready
        if ccs.exists:
            for cc in ccs:
                if self.structures(UnitTypeId.BARRACKS).closer_than(5, cc).amount < 2 and self.already_pending(UnitTypeId.BARRACKS) < 2:
                    if self.can_afford(UnitTypeId.BARRACKS):
                        await self.build(UnitTypeId.BARRACKS, near=cc.position)

    async def build_marines(self):
        if self.units(UnitTypeId.MARINE).amount < self.townhalls.amount * 10:
            ccs = self.townhalls(UnitTypeId.COMMANDCENTER).ready
            if ccs.exists:
                for cc in ccs:
                    if self.structures(UnitTypeId.BARRACKS).closer_than(20, cc).amount > 0:
                        for rax in self.structures(UnitTypeId.BARRACKS).closer_than(20, cc).ready.idle:
                            if self.can_afford(UnitTypeId.MARINE):
                                rax.train(UnitTypeId.MARINE)

    async def marine_patrol(self):
        mrns = self.units(UnitTypeId.MARINE)
        ccs = self.townhalls

        if mrns.exists:
            for mr in mrns:
                if self.enemy_units.in_attack_range_of(mr, 20).amount > 0:
                    nearest_enemy = self.enemy_units.in_attack_range_of(mr, 20).closest_to(mr)
                    mr.attack(nearest_enemy)
                else:
                    if self.tick5:
                        positive_pos = self.units.closer_than(5, mr).center
                        # returned a point2
                        negative_pos = self.units.closer_than(3, mr).center
                        # returned another point2
                        calc_pos = positive_pos + positive_pos.direction_vector(negative_pos)
                        neighbors = self.units.closer_than(4, mr)
                        neighbor_facing_vec = []
                        neighbor_heading = 0
                        count = 0
                        for nh in neighbors:
                            neighbor_heading += nh.facing
                            count += 1
                        if count != 0:
                            neighbor_facing_vec = neighbor_heading / count
                            neighbor_facing_vec = [math.cos(neighbor_facing_vec), math.sin(neighbor_facing_vec)]
                            #print(neighbor_facing_vec)
                            calc_pos = calc_pos + (neighbor_facing_vec * 40)
                            
                        mr.move(calc_pos)

                


def main():
    run_game(
        maps.get("(2)CatalystLE"),
        [Bot(Race.Terran, BBBot()),
         Computer(Race.Terran, Difficulty.Easy)],
        realtime=False,
    )


if __name__ == "__main__":
    main()
# Out:
# 2023-02-04 14:35:40.395 | INFO     | sc2.protocol:_execute:72 - Client status changed to Status.launched (was None)
# 2023-02-04 14:35:40.396 | INFO     | sc2.controller:create_game:37 - Creating new game
# 2023-02-04 14:35:40.396 | INFO     | sc2.controller:create_game:38 - Map:     (2)CatalystLE
# 2023-02-04 14:35:40.397 | INFO     | sc2.controller:create_game:39 - Players: Bot BBBot(Terran), Computer Easy(Terran, RandomBuild)
# 2023-02-04 14:35:40.398 | INFO     | sc2.protocol:_execute:72 - Client status changed to Status.init_game (was Status.launched)
# 2023-02-04 14:35:45.673 | INFO     | sc2.protocol:_execute:72 - Client status changed to Status.in_game (was None)
# 2023-02-04 14:35:45.674 | INFO     | sc2.main:_play_game:221 - Player 1 - Bot BBBot(Terran)
# 2023-02-04 14:38:08.828 | INFO     | sc2.protocol:_execute:72 - Client status changed to Status.ended (was Status.in_game)
# 2023-02-04 14:38:08.829 | INFO     | sc2.main:_play_game:228 - Result for player 1 - Bot BBBot(Terran): Defeat
# 2023-02-04 14:38:09.822 | INFO     | sc2.protocol:__request:48 - Cannot receive: Game has already ended.
# 2023-02-04 14:38:09.823 | INFO     | sc2.sc2process:_close_connection:231 - Closing connection at 63005...
# 2023-02-04 14:38:09.823 | INFO     | sc2.sc2process:kill_all:33 - kill_switch: Process cleanup for 6 processes
